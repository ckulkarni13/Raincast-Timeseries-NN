# %% [markdown]
# # Final Project: INFO6106 Neural Modeling Methods & Tools
# # Predicting 2 Day in Advanced

# %% [markdown]
# # Lake Effect Precipitation Prediction using CNN and RNN
#
# (2 days in Advance)

# %% [markdown]
# **Import necessary libraries**

# %%
import os
import pandas as pd
import numpy as np
from tqdm import tqdm
from datetime import date

import pickle
import cv2

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.13.1

# %%
from keras.models import Model
from keras.layers import Input, Conv3D, BatchNormalization, MaxPooling3D, Flatten, Dense, LSTM, Concatenate, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint

# %% [markdown]
# ## Read `meteorological_data` data

# %%
meteorological_data_original = pd.read_csv('meteorological_data.csv')

meteorological_data_full = meteorological_data_original.copy()
meteorological_data_full
# Out:
#               DateTime_UTC  Temp_F  RH_pct  Wind_Spd_mph  Wind_Direction_deg  \
# 0      2006-10-01 00:00:00    48.0    86.0             7                 150
# 1      2006-10-01 01:00:00    48.0    86.0             8                 150
# 2      2006-10-01 02:00:00    48.0    86.0             6                 150
# 3      2006-10-01 03:00:00    48.0    86.0             8                 150
# 4      2006-10-01 04:00:00    48.0    89.0             5                 150
# ...                    ...     ...     ...           ...                 ...
# 48116  2017-03-31 19:00:00    40.0    76.0             0                   0
# 48117  2017-03-31 20:00:00    39.0    72.0             3                  20
# 48118  2017-03-31 21:00:00    35.0    84.0             5                 300
# 48119  2017-03-31 22:00:00    34.0    85.0             0                   0
# 48120  2017-03-31 23:00:00    30.0    88.0             0                   0
#
#        Low_Cloud_Ht_ft  Visibility_mi  Atm_Press_hPa  Precip_in
# 0                 4100             10          984.0       0.00
# 1                 6000             10          983.7       0.00
# 2                 5500             10          982.7       0.00
# 3                 6000             10          982.0       0.00
# 4                 2200              8          982.0       0.02
# ...                ...            ...            ...        ...
# 48116             5000             10          991.7       0.00
# 48117             5000             10          992.3       0.00
# 48118             5000             10          993.3       0.00
# 48119             5000             10          993.3       0.00
# 48120             5000             10          993.7       0.00
#
# [48121 rows x 9 columns]

# %% [markdown]
# **Convert `DateTime_UTC` to Datetime format**

# %%
meteorological_data_full['DateTime_UTC'] = pd.to_datetime(meteorological_data_full['DateTime_UTC'], format='%Y-%m-%d %H:%M:%S')

# %% [markdown]
# **Resample Hourly Meteorological Data to Daily Averages and Sums**

# %%
# Resample hourly data into daily data
daily_data = meteorological_data_full.groupby(meteorological_data_full['DateTime_UTC'].dt.date).agg({
   'Temp_F': 'mean',    
    'RH_pct': 'mean',    
    'Wind_Spd_mph': 'mean',     
    'Atm_Press_hPa': 'mean',
    'Low_Cloud_Ht_ft': 'mean',
    'Visibility_mi': 'mean',    
    'Precip_in': 'sum',     
}).reset_index()

# %%
daily_data.dtypes
# Out:
# DateTime_UTC        object
# Temp_F             float64
# RH_pct             float64
# Wind_Spd_mph       float64
# Atm_Press_hPa      float64
# Low_Cloud_Ht_ft    float64
# Visibility_mi      float64
# Precip_in          float64
# dtype: object

# %%
daily_data
# Out:
#      DateTime_UTC     Temp_F     RH_pct  Wind_Spd_mph  Atm_Press_hPa  \
# 0      2006-10-01  51.500000  74.958333      5.166667     991.275000
# 1      2006-10-02  62.750000  73.166667      5.250000     990.054167
# 2      2006-10-03  59.875000  81.458333      4.875000     993.491667
# 3      2006-10-04  55.625000  72.041667      9.833333     997.937500
# 4      2006-10-05  49.208333  75.791667      5.083333    1002.075000
# ...           ...        ...        ...           ...            ...
# 2000   2017-03-27  38.250000  88.250000      4.750000     991.920833
# 2001   2017-03-28  38.833333  86.041667      4.666667     995.729167
# 2002   2017-03-29  37.458333  77.708333      4.750000    1000.233333
# 2003   2017-03-30  36.291667  78.041667      7.458333     993.387500
# 2004   2017-03-31  37.916667  71.875000      7.500000     991.812500
#
#       Low_Cloud_Ht_ft  Visibility_mi  Precip_in
# 0         4683.333333       9.833333       0.03
# 1         3450.000000       9.166667       0.01
# 2         3595.833333       7.250000       2.02
# 3         1908.333333       9.875000       0.01
# 4         1783.333333       7.833333       0.56
# ...               ...            ...        ...
# 2000       808.333333       8.166667       0.03
# 2001      7187.500000       6.750000       0.00
# 2002      6237.500000       8.208333       0.00
# 2003      2866.666667       8.375000       0.10
# 2004      3950.000000       9.750000       0.00
#
# [2005 rows x 8 columns]

# %% [markdown]
# ### **Assign 2nd next Day's Precipitation to current days features to predict Two Days in advance**
#
# adds a new column `Precip_next`. This column represents the precipitation value of the next day by shifting the `Precip_in` column upwards by one row.

# %%
daily_data['Precip_next']=daily_data['Precip_in'].shift(-2)

daily_data.dropna(subset=['Precip_next'],inplace=True)

# %%
daily_data
# Out:
#      DateTime_UTC     Temp_F     RH_pct  Wind_Spd_mph  Atm_Press_hPa  \
# 0      2006-10-01  51.500000  74.958333      5.166667     991.275000
# 1      2006-10-02  62.750000  73.166667      5.250000     990.054167
# 2      2006-10-03  59.875000  81.458333      4.875000     993.491667
# 3      2006-10-04  55.625000  72.041667      9.833333     997.937500
# 4      2006-10-05  49.208333  75.791667      5.083333    1002.075000
# ...           ...        ...        ...           ...            ...
# 1998   2017-03-25  37.833333  81.875000      8.208333     997.925000
# 1999   2017-03-26  41.666667  89.625000      4.250000     991.770833
# 2000   2017-03-27  38.250000  88.250000      4.750000     991.920833
# 2001   2017-03-28  38.833333  86.041667      4.666667     995.729167
# 2002   2017-03-29  37.458333  77.708333      4.750000    1000.233333
#
#       Low_Cloud_Ht_ft  Visibility_mi  Precip_in  Precip_next
# 0         4683.333333       9.833333       0.03         2.02
# 1         3450.000000       9.166667       0.01         0.01
# 2         3595.833333       7.250000       2.02         0.56
# 3         1908.333333       9.875000       0.01         0.00
# 4         1783.333333       7.833333       0.56         0.00
# ...               ...            ...        ...          ...
# 1998      2537.500000       9.541667       0.11         0.03
# 1999       950.000000       6.875000       0.09         0.00
# 2000       808.333333       8.166667       0.03         0.00
# 2001      7187.500000       6.750000       0.00         0.10
# 2002      6237.500000       8.208333       0.00         0.00
#
# [2003 rows x 9 columns]

# %% [markdown]
# **We need to remove March 30th & 31st for every year because when we shifted the precipitation values, it took on the value of October 1st and 2nd, which is not desired.**

# %%
year_list = [2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017]
remove_dates = []
for y in year_list:
    # Create date objects for March 31st and March 30th
    mar_31 = date(y, 3, 31)
    mar_30 = date(y, 3, 30)
    
    # Append dates to the list
    remove_dates.append(mar_31)
    remove_dates.append(mar_30)

# Print the list of dates to be removed
remove_dates
# Out:
# [datetime.date(2006, 3, 31),
#  datetime.date(2006, 3, 30),
#  datetime.date(2007, 3, 31),
#  datetime.date(2007, 3, 30),
#  datetime.date(2008, 3, 31),
#  datetime.date(2008, 3, 30),
#  datetime.date(2009, 3, 31),
#  datetime.date(2009, 3, 30),
#  datetime.date(2010, 3, 31),
#  datetime.date(2010, 3, 30),
#  datetime.date(2011, 3, 31),
#  datetime.date(2011, 3, 30),
#  datetime.date(2012, 3, 31),
#  datetime.date(2012, 3, 30),
#  datetime.date(2013, 3, 31),
#  datetime.date(2013, 3, 30),
#  datetime.date(2014, 3, 31),
#  datetime.date(2014, 3, 30),
#  datetime.date(2015, 3, 31),
#  datetime.date(2015, 3, 30),
#  datetime.date(2016, 3, 31),
#  datetime.date(2016, 3, 30),
#  datetime.date(2017, 3, 31),
#  datetime.date(2017, 3, 30)]

# %%
daily_data = daily_data[~daily_data['DateTime_UTC'].isin(remove_dates)].reset_index(drop=True)
daily_data
# Out:
#      DateTime_UTC     Temp_F     RH_pct  Wind_Spd_mph  Atm_Press_hPa  \
# 0      2006-10-01  51.500000  74.958333      5.166667     991.275000
# 1      2006-10-02  62.750000  73.166667      5.250000     990.054167
# 2      2006-10-03  59.875000  81.458333      4.875000     993.491667
# 3      2006-10-04  55.625000  72.041667      9.833333     997.937500
# 4      2006-10-05  49.208333  75.791667      5.083333    1002.075000
# ...           ...        ...        ...           ...            ...
# 1978   2017-03-25  37.833333  81.875000      8.208333     997.925000
# 1979   2017-03-26  41.666667  89.625000      4.250000     991.770833
# 1980   2017-03-27  38.250000  88.250000      4.750000     991.920833
# 1981   2017-03-28  38.833333  86.041667      4.666667     995.729167
# 1982   2017-03-29  37.458333  77.708333      4.750000    1000.233333
#
#       Low_Cloud_Ht_ft  Visibility_mi  Precip_in  Precip_next
# 0         4683.333333       9.833333       0.03         2.02
# 1         3450.000000       9.166667       0.01         0.01
# 2         3595.833333       7.250000       2.02         0.56
# 3         1908.333333       9.875000       0.01         0.00
# 4         1783.333333       7.833333       0.56         0.00
# ...               ...            ...        ...          ...
# 1978      2537.500000       9.541667       0.11         0.03
# 1979       950.000000       6.875000       0.09         0.00
# 1980       808.333333       8.166667       0.03         0.00
# 1981      7187.500000       6.750000       0.00         0.10
# 1982      6237.500000       8.208333       0.00         0.00
#
# [1983 rows x 9 columns]

# %% [markdown]
# **Min, Max and Mean Precipitation values**

# %%
mean_precip = daily_data['Precip_in'].mean()
min_precip = daily_data['Precip_in'].min()
max_precip = daily_data['Precip_in'].max()

print("Mean precipitation:", mean_precip)
print("Minimum precipitation:", min_precip)
print("Maximum precipitation:", max_precip)
# Out:
# Mean precipitation: 0.06043872919818467
# Minimum precipitation: 0.0
# Maximum precipitation: 2.02

# %% [markdown]
# **Categorizing Precipitation Data**
#
# Categorize precipitation data into different levels ('No Rain', 'Light Rain', 'Moderate Rain', 'Heavy Rain')

# %%
# Define conditions based on real scenarios
conditions = [
    (daily_data['Precip_next'] == 0.0),
    (daily_data['Precip_next'] > 0) & (daily_data['Precip_next'] <= 0.05),
    (daily_data['Precip_next'] > 0.05) & (daily_data['Precip_next'] <= 0.25),
    (daily_data['Precip_next'] > 0.25)
]

# Define corresponding labels for each condition
names = ['No Rain', 'Light Rain', 'Moderate Rain', 'Heavy Rain']

# Replace values in 'target' column with corresponding labels based on conditions 
daily_data['target'] = np.select(conditions, names, default='')
daily_data.head()
# Out:
#   DateTime_UTC     Temp_F     RH_pct  Wind_Spd_mph  Atm_Press_hPa  \
# 0   2006-10-01  51.500000  74.958333      5.166667     991.275000
# 1   2006-10-02  62.750000  73.166667      5.250000     990.054167
# 2   2006-10-03  59.875000  81.458333      4.875000     993.491667
# 3   2006-10-04  55.625000  72.041667      9.833333     997.937500
# 4   2006-10-05  49.208333  75.791667      5.083333    1002.075000
#
#    Low_Cloud_Ht_ft  Visibility_mi  Precip_in  Precip_next      target
# 0      4683.333333       9.833333       0.03         2.02  Heavy Rain
# 1      3450.000000       9.166667       0.01         0.01  Light Rain
# 2      3595.833333       7.250000       2.02         0.56  Heavy Rain
# 3      1908.333333       9.875000       0.01         0.00     No Rain
# 4      1783.333333       7.833333       0.56         0.00     No Rain

# %% [markdown]
# **Class distribution in the `target` column after categorization**

# %%
print(daily_data['target'].value_counts())
# Out:
# No Rain          1047
# Light Rain        488
# Moderate Rain     325
# Heavy Rain        123
# Name: target, dtype: int64

# %% [markdown]
# **One-Hot Encoding the Target Column**

# %%
# Perform one-hot encoding directly on the DataFrame with specified categories order
one_hot_encoded = pd.get_dummies(daily_data['target'], prefix='', prefix_sep='').reindex(columns=['No Rain', 'Light Rain', 'Moderate Rain', 'Heavy Rain'], fill_value=0)

# Convert the data type to integer
one_hot_encoded = one_hot_encoded.astype(int)

# Concatenate the one-hot encoded columns to the DataFrame
daily_data = pd.concat([daily_data, one_hot_encoded], axis=1)

# Display the updated DataFrame
daily_data.head()
# Out:
#   DateTime_UTC     Temp_F     RH_pct  Wind_Spd_mph  Atm_Press_hPa  \
# 0   2006-10-01  51.500000  74.958333      5.166667     991.275000
# 1   2006-10-02  62.750000  73.166667      5.250000     990.054167
# 2   2006-10-03  59.875000  81.458333      4.875000     993.491667
# 3   2006-10-04  55.625000  72.041667      9.833333     997.937500
# 4   2006-10-05  49.208333  75.791667      5.083333    1002.075000
#
#    Low_Cloud_Ht_ft  Visibility_mi  Precip_in  Precip_next      target  \
# 0      4683.333333       9.833333       0.03         2.02  Heavy Rain
# 1      3450.000000       9.166667       0.01         0.01  Light Rain
# 2      3595.833333       7.250000       2.02         0.56  Heavy Rain
# 3      1908.333333       9.875000       0.01         0.00     No Rain
# 4      1783.333333       7.833333       0.56         0.00     No Rain
#
#    No Rain  Light Rain  Moderate Rain  Heavy Rain
# 0        0           0              0           1
# 1        0           1              0           0
# 2        0           0              0           1
# 3        1           0              0           0
# 4        1           0              0           0

# %% [markdown]
# **Dividing the meteorological data to `features` and `lables`**

# %%
features = daily_data.columns[1:8]
features
# Out:
# Index(['Temp_F', 'RH_pct', 'Wind_Spd_mph', 'Atm_Press_hPa', 'Low_Cloud_Ht_ft',
#        'Visibility_mi', 'Precip_in'],
#       dtype='object')

# %%
labels = daily_data.columns[-4:]
labels
# Out:
# Index(['No Rain', 'Light Rain', 'Moderate Rain', 'Heavy Rain'], dtype='object')

# %% [markdown]
# ------

# %% [markdown]
# ## Scale the features

# %%
# Convert 'DateTime_UTC' column to datetime type
daily_data['DateTime_UTC'] = pd.to_datetime(daily_data['DateTime_UTC'])

# Define scaler
scaler = MinMaxScaler()

# Scale data for October 2006 to March 2016
mask_2006_to_2016 = (daily_data['DateTime_UTC'] >= '2006-10-01') & (daily_data['DateTime_UTC'] < '2016-04-01')
daily_data.loc[mask_2006_to_2016, ['Temp_F', 'RH_pct', 'Wind_Spd_mph', 'Atm_Press_hPa', 'Low_Cloud_Ht_ft', 'Visibility_mi', 'Precip_in']] = scaler.fit_transform(daily_data.loc[mask_2006_to_2016, ['Temp_F', 'RH_pct', 'Wind_Spd_mph', 'Atm_Press_hPa', 'Low_Cloud_Ht_ft', 'Visibility_mi', 'Precip_in']])

# Scale data for October 2016 to March 2017
mask_2016_to_2017 = (daily_data['DateTime_UTC'] >= '2016-10-01') & (daily_data['DateTime_UTC'] < '2017-04-01')
daily_data.loc[mask_2016_to_2017, ['Temp_F', 'RH_pct', 'Wind_Spd_mph', 'Atm_Press_hPa', 'Low_Cloud_Ht_ft', 'Visibility_mi', 'Precip_in']] = scaler.fit_transform(daily_data.loc[mask_2016_to_2017, ['Temp_F', 'RH_pct', 'Wind_Spd_mph', 'Atm_Press_hPa', 'Low_Cloud_Ht_ft', 'Visibility_mi', 'Precip_in']])

daily_data['Date'] = daily_data['DateTime_UTC'].dt.date

# Print the scaled DataFrame
daily_data
# Out:
#      DateTime_UTC    Temp_F    RH_pct  Wind_Spd_mph  Atm_Press_hPa  \
# 0      2006-10-01  0.671649  0.695153      0.256351       0.556518
# 1      2006-10-02  0.810825  0.667730      0.260970       0.528941
# 2      2006-10-03  0.775258  0.794643      0.240185       0.606588
# 3      2006-10-04  0.722680  0.650510      0.515012       0.707012
# 4      2006-10-05  0.643299  0.707908      0.251732       0.800471
# ...           ...       ...       ...           ...            ...
# 1978   2017-03-25  0.463415  0.756458      0.377083       0.663475
# 1979   2017-03-26  0.529412  0.893727      0.179167       0.495098
# 1980   2017-03-27  0.470588  0.869373      0.204167       0.499202
# 1981   2017-03-28  0.480631  0.830258      0.200000       0.603397
# 1982   2017-03-29  0.456958  0.682657      0.204167       0.726630
#
#       Low_Cloud_Ht_ft  Visibility_mi  Precip_in  Precip_next         target  \
# 0            0.187333       0.981043   0.014851         2.02     Heavy Rain
# 1            0.138000       0.905213   0.004950         0.01     Light Rain
# 2            0.143833       0.687204   1.000000         0.56     Heavy Rain
# 3            0.076333       0.985782   0.004950         0.00        No Rain
# 4            0.071333       0.753555   0.277228         0.00        No Rain
# ...               ...            ...        ...          ...            ...
# 1978         0.093074       0.946341   0.142857         0.03     Light Rain
# 1979         0.023814       0.634146   0.116883         0.00        No Rain
# 1980         0.017633       0.785366   0.038961         0.00        No Rain
# 1981         0.295946       0.619512   0.000000         0.10  Moderate Rain
# 1982         0.254499       0.790244   0.000000         0.00        No Rain
#
#       No Rain  Light Rain  Moderate Rain  Heavy Rain        Date
# 0           0           0              0           1  2006-10-01
# 1           0           1              0           0  2006-10-02
# 2           0           0              0           1  2006-10-03
# 3           1           0              0           0  2006-10-04
# 4           1           0              0           0  2006-10-05
# ...       ...         ...            ...         ...         ...
# 1978        0           1              0           0  2017-03-25
# 1979        1           0              0           0  2017-03-26
# 1980        1           0              0           0  2017-03-27
# 1981        0           0              1           0  2017-03-28
# 1982        1           0              0           0  2017-03-29
#
# [1983 rows x 15 columns]

# %% [markdown]
# ---------

# %% [markdown]
# ## Read `filtered_les_cld_imgs` data

# %%
img_data_original = pd.read_csv('filtered_les_cld_imgs.csv')

img_data = img_data_original.copy()
img_data.head()
# Out:
#           DateTime_UTC                                       Lake_data_2D
# 0  2006-10-01 14:00:00  [array([       nan,        nan,        nan,   ...
# 1  2006-10-01 15:00:00  [array([       nan,        nan,        nan,   ...
# 2  2006-10-01 16:00:00  [array([   nan,    nan,    nan,    nan,    nan...
# 3  2006-10-01 17:00:00  [array([ nan,  nan,  nan,  nan,  nan,  nan,  n...
# 4  2006-10-01 18:00:00  [array([   nan,    nan,    nan,    nan,    nan...

# %% [markdown]
# **Convert `DateTime_UTC` to Datetime format**

# %%
img_data['DateTime_UTC'] = pd.to_datetime(img_data['DateTime_UTC'], format='%Y-%m-%d %H:%M:%S')

# %%
img_data['Date'] = img_data['DateTime_UTC'].dt.date
img_data.head()
# Out:
#          DateTime_UTC                                       Lake_data_2D  \
# 0 2006-10-01 14:00:00  [array([       nan,        nan,        nan,   ...
# 1 2006-10-01 15:00:00  [array([       nan,        nan,        nan,   ...
# 2 2006-10-01 16:00:00  [array([   nan,    nan,    nan,    nan,    nan...
# 3 2006-10-01 17:00:00  [array([ nan,  nan,  nan,  nan,  nan,  nan,  n...
# 4 2006-10-01 18:00:00  [array([   nan,    nan,    nan,    nan,    nan...
#
#          Date
# 0  2006-10-01
# 1  2006-10-01
# 2  2006-10-01
# 3  2006-10-01
# 4  2006-10-01

# %% [markdown]
# ----

# %% [markdown]
# ### Creating the Training Data Sequences of Cloud images and meteorological data

# %%
sequence_length = 7
year_list = [2006,2007,2008,2009,2012,2013,2014,2015]

# %%
img_data['Date'] = img_data['DateTime_UTC'].dt.date

# %%
all_meteo_seq_list = []
all_label_list = []
all_video_list = []

for y in tqdm(year_list):
    start_date = date(y, 10, 1)
    end_date = date(y+1, 3, 31)

    train_meteo_data = daily_data[(daily_data['Date']>=start_date)
                                  &(daily_data['Date']<=end_date)].reset_index(drop=True) 
    
    train_img_data = img_data[(img_data['Date']>=start_date)
                             &(img_data['Date']<=end_date)]

    meteo_seq_list = []
    label_list = []
    date_list = []
    video_list = []

    for i in range(sequence_length-1, len(train_meteo_data)):

        meteo_seq = train_meteo_data[i - (sequence_length-1) : i+1][features].values
        label = train_meteo_data[labels].values[i]
        curr_date = train_meteo_data['Date'].values[i]

        meteo_seq_list.append(meteo_seq)
        label_list.append(label)
        date_list.append(curr_date)

        curr_img_data = train_img_data[train_img_data.Date == curr_date]
        image_list=[]

        for i in range(len(curr_img_data)):
            data_sample_2d = curr_img_data['Lake_data_2D'].values[i]
            data_sample_2d_array = np.array(eval(data_sample_2d.replace('array(', '').replace('nan', 'np.nan').replace('\n', '').replace(')', '')))
            data_sample_2d_array_resized = cv2.resize(data_sample_2d_array, (64, 64))
            data_sample_2d_array_resized = np.expand_dims(data_sample_2d_array_resized, axis=-1)
            image_list.append(data_sample_2d_array_resized)

        array_3d = np.stack(image_list, axis=0)
        array_3d_filled = np.nan_to_num(array_3d, nan=0.0)
        video_list.append(array_3d_filled)
            
    meteo_seq_array = np.stack(meteo_seq_list, axis=0)    
    label_array = np.stack(label_list, axis=0)
    video_array = np.stack(video_list, axis=0)
    
    all_meteo_seq_list.append(meteo_seq_array)
    all_label_list.append(label_array)
    all_video_list.append(video_array)
# Out:
# 100%|██████████| 8/8 [03:25<00:00, 25.74s/it]

# %%
train_meteo = np.concatenate(all_meteo_seq_list, axis=0)
train_video = np.concatenate(all_video_list, axis=0)
train_label = np.concatenate(all_label_list, axis=0)

# %%
train_meteo.shape, train_video.shape, train_label.shape
# Out:
# ((1394, 7, 7), (1394, 9, 64, 64, 1), (1394, 4))

# %% [markdown]
# ### Creating the Testing Data Sequences of Cloud images and meteorological data

# %%
sequence_length = 7
year_list = [2016]

# %%
all_meteo_seq_list = []
all_label_list = []
all_video_list = []

for y in tqdm(year_list):
    start_date = date(y, 10, 1)
    end_date = date(y+1, 3, 31)

    train_meteo_data = daily_data[(daily_data['Date']>=start_date)
                                  &(daily_data['Date']<=end_date)].reset_index(drop=True) 
    
    train_img_data = img_data[(img_data['Date']>=start_date)
                             &(img_data['Date']<=end_date)]

    meteo_seq_list = []
    label_list = []
    date_list = []
    video_list = []

    for i in range(sequence_length-1, len(train_meteo_data)):

        meteo_seq = train_meteo_data[i - (sequence_length-1) : i+1][features].values
        label = train_meteo_data[labels].values[i]
        curr_date = train_meteo_data['Date'].values[i]

        meteo_seq_list.append(meteo_seq)
        label_list.append(label)
        date_list.append(curr_date)

        curr_img_data = train_img_data[train_img_data.Date == curr_date]
        image_list=[]

        for i in range(len(curr_img_data)):
            data_sample_2d = curr_img_data['Lake_data_2D'].values[i]
            data_sample_2d_array = np.array(eval(data_sample_2d.replace('array(', '').replace('nan', 'np.nan').replace('\n', '').replace(')', '')))
            data_sample_2d_array_resized = cv2.resize(data_sample_2d_array, (64, 64))
            data_sample_2d_array_resized = np.expand_dims(data_sample_2d_array_resized, axis=-1)
            image_list.append(data_sample_2d_array_resized)

        array_3d = np.stack(image_list, axis=0)
        array_3d_filled = np.nan_to_num(array_3d, nan=0.0)
        video_list.append(array_3d_filled)
            
    meteo_seq_array = np.stack(meteo_seq_list, axis=0)    
    label_array = np.stack(label_list, axis=0)
    video_array = np.stack(video_list, axis=0)
    
    all_meteo_seq_list.append(meteo_seq_array)
    all_label_list.append(label_array)
    all_video_list.append(video_array)
# Out:
# 100%|██████████| 1/1 [00:26<00:00, 26.15s/it]

# %%
test_meteo = np.concatenate(all_meteo_seq_list, axis=0)
test_video = np.concatenate(all_video_list, axis=0)
test_label = np.concatenate(all_label_list, axis=0)

# %%
test_meteo.shape, test_video.shape, test_label.shape
# Out:
# ((174, 7, 7), (174, 9, 64, 64, 1), (174, 4))

# %% [markdown]
# ---

# %% [markdown]
# # Convolutional Neural Network + Recurrent Neural Network Architecture
#
# ## Hybrid Model 1

# %% [markdown]
# **To balance the weights and pay more attention to underrepresented classes, we will calculate the class weights and pass this during training**

# %%
category_counts = one_hot_encoded.sum()

total_samples = one_hot_encoded.sum().sum()

class_weights = total_samples / (4 * category_counts)

class_weight_dict = {i: class_weights[i] for i in range(len(class_weights))}

# %%
class_weight_dict
# Out:
# {0: 0.47349570200573066,
#  1: 1.0158811475409837,
#  2: 1.5253846153846153,
#  3: 4.030487804878049}

# %% [markdown]
# Model Architecture
# - One CNN layer
# - Three RNN LSTM layers, with verying units throughout the layers and activations as desired
# - BatchNormalization for each layers

# %%
# CNN Model
cnn_input = Input(shape=(9, 64, 64, 1))
cnn = Conv3D(filters=32, kernel_size=(3, 3, 3), activation='relu', padding='same')(cnn_input)
cnn = BatchNormalization()(cnn)
cnn = MaxPooling3D(pool_size=(2, 2, 2))(cnn)

cnn = Flatten()(cnn)
cnn_output = Dense(32, activation='relu')(cnn)

# RNN Model
rnn_input = Input(shape=(7, 7))
rnn = LSTM(128, return_sequences=True)(rnn_input)
rnn = BatchNormalization()(rnn)
rnn = LSTM(64, return_sequences=True)(rnn)
rnn = BatchNormalization()(rnn)
rnn = LSTM(32, return_sequences=False)(rnn)
rnn = BatchNormalization()(rnn)
rnn_output = Dense(24, activation='relu')(rnn)

# Concatenation and final layers
concatenated = Concatenate()([cnn_output, rnn_output])

final_dense = Dense(32, activation='relu')(concatenated)
final_output = Dense(4, activation='softmax')(final_dense)

# Final model assembly
model = Model(inputs=[cnn_input, rnn_input], outputs=final_output)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_18 (InputLayer)       [(None, 7, 7)]               0         []
#
#  lstm_22 (LSTM)              (None, 7, 128)               69632     ['input_18[0][0]']
#
#  input_17 (InputLayer)       [(None, 9, 64, 64, 1)]       0         []
#
#  batch_normalization_31 (Ba  (None, 7, 128)               512       ['lstm_22[0][0]']
#  tchNormalization)
#
#  conv3d_8 (Conv3D)           (None, 9, 64, 64, 32)        896       ['input_17[0][0]']
#
#  lstm_23 (LSTM)              (None, 7, 64)                49408     ['batch_normalization_31[0][0]
#                                                                     ']
#
#  batch_normalization_30 (Ba  (None, 9, 64, 64, 32)        128       ['conv3d_8[0][0]']
#  tchNormalization)
#
#  batch_normalization_32 (Ba  (None, 7, 64)                256       ['lstm_23[0][0]']
#  tchNormalization)
#
#  max_pooling3d_8 (MaxPoolin  (None, 4, 32, 32, 32)        0         ['batch_normalization_30[0][0]
#  g3D)                                                               ']
#
#  lstm_24 (LSTM)              (None, 32)                   12416     ['batch_normalization_32[0][0]
#                                                                     ']
#
#  flatten_8 (Flatten)         (None, 131072)               0         ['max_pooling3d_8[0][0]']
#
#  batch_normalization_33 (Ba  (None, 32)                   128       ['lstm_24[0][0]']
#  tchNormalization)
#
#  dense_32 (Dense)            (None, 32)                   4194336   ['flatten_8[0][0]']
#
#  dense_33 (Dense)            (None, 24)                   792       ['batch_normalization_33[0][0]
#                                                                     ']
#
#  concatenate_8 (Concatenate  (None, 56)                   0         ['dense_32[0][0]',
#  )                                                                   'dense_33[0][0]']
#
#  dense_34 (Dense)            (None, 32)                   1824      ['concatenate_8[0][0]']
#
#  dense_35 (Dense)            (None, 4)                    132       ['dense_34[0][0]']
#
# ==================================================================================================
# Total params: 4330460 (16.52 MB)
# Trainable params: 4329948 (16.52 MB)
# Non-trainable params: 512 (2.00 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# **Model Fitting**

# %%
history = model.fit(
    [train_video, train_meteo],
    train_label,                
    epochs=20,                 
    batch_size=32,               
    class_weight=class_weight_dict,
    validation_split=0.2
)
# Out:
# Epoch 1/20
# 35/35 [==============================] - 75s 2s/step - loss: 3.4991 - accuracy: 0.2108 - val_loss: 1.6148 - val_accuracy: 0.1649
# Epoch 2/20
# 35/35 [==============================] - 68s 2s/step - loss: 1.4080 - accuracy: 0.2377 - val_loss: 1.3808 - val_accuracy: 0.2473
# Epoch 3/20
# 35/35 [==============================] - 68s 2s/step - loss: 1.3678 - accuracy: 0.2592 - val_loss: 1.3671 - val_accuracy: 0.1864
# Epoch 4/20
# 35/35 [==============================] - 68s 2s/step - loss: 1.3631 - accuracy: 0.2987 - val_loss: 1.3632 - val_accuracy: 0.1864
# Epoch 5/20
# 35/35 [==============================] - 67s 2s/step - loss: 1.3407 - accuracy: 0.3274 - val_loss: 1.3508 - val_accuracy: 0.2079
# Epoch 6/20
# 35/35 [==============================] - 68s 2s/step - loss: 1.3220 - accuracy: 0.3283 - val_loss: 1.3705 - val_accuracy: 0.1971
# Epoch 7/20
# 35/35 [==============================] - 68s 2s/step - loss: 1.3119 - accuracy: 0.3552 - val_loss: 1.3352 - val_accuracy: 0.3011
# Epoch 8/20
# 35/35 [==============================] - 68s 2s/step - loss: 1.3004 - accuracy: 0.3283 - val_loss: 1.3788 - val_accuracy: 0.2186
# Epoch 9/20
# 35/35 [==============================] - 68s 2s/step - loss: 1.2843 - accuracy: 0.3444 - val_loss: 1.3967 - val_accuracy: 0.2437
# Epoch 10/20
# 35/35 [==============================] - 68s 2s/step - loss: 1.2582 - accuracy: 0.3722 - val_loss: 1.3760 - val_accuracy: 0.3011
# Epoch 11/20
# 35/35 [==============================] - 68s 2s/step - loss: 1.2432 - accuracy: 0.3498 - val_loss: 1.3661 - val_accuracy: 0.2760
# Epoch 12/20
# 35/35 [==============================] - 68s 2s/step - loss: 1.2100 - accuracy: 0.3919 - val_loss: 1.3086 - val_accuracy: 0.3405
# Epoch 13/20
# 35/35 [==============================] - 68s 2s/step - loss: 1.2092 - accuracy: 0.3883 - val_loss: 1.3138 - val_accuracy: 0.3513
# Epoch 14/20
# 35/35 [==============================] - 68s 2s/step - loss: 1.2038 - accuracy: 0.3892 - val_loss: 1.4013 - val_accuracy: 0.2652
# Epoch 15/20
# 35/35 [==============================] - 68s 2s/step - loss: 1.1497 - accuracy: 0.4072 - val_loss: 1.3324 - val_accuracy: 0.3656
# Epoch 16/20
# 35/35 [==============================] - 67s 2s/step - loss: 1.1521 - accuracy: 0.4152 - val_loss: 1.3929 - val_accuracy: 0.2724
# Epoch 17/20
# 35/35 [==============================] - 68s 2s/step - loss: 1.1254 - accuracy: 0.4152 - val_loss: 1.4668 - val_accuracy: 0.3118
# Epoch 18/20
# 35/35 [==============================] - 68s 2s/step - loss: 1.0868 - accuracy: 0.4556 - val_loss: 1.4199 - val_accuracy: 0.3011
# Epoch 19/20
# 35/35 [==============================] - 68s 2s/step - loss: 1.1143 - accuracy: 0.4493 - val_loss: 1.4136 - val_accuracy: 0.2832
# Epoch 20/20
# 35/35 [==============================] - 68s 2s/step - loss: 1.0765 - accuracy: 0.4296 - val_loss: 1.3513 - val_accuracy: 0.3692

# %% [markdown]
# **Plots for training & validation accuracy & loss values**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# **From the above plots it seems the model is overfitting**

# %% [markdown]
# **Evaluate the model on the test data**

# %%
# Evaluate the model on the test data
test_loss, test_accuracy = model.evaluate([test_video, test_meteo], test_label)

print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# 6/6 [==============================] - 1s 118ms/step - loss: 1.6663 - accuracy: 0.1782
# Test Loss: 1.666297435760498
# Test Accuracy: 0.1781609207391739

# %% [markdown]
# **Prediction on the test dataset**

# %%
# Predict the test dataset
pred_label = model.predict([test_video, test_meteo])

# Convert predictions from one-hot to labels
pred_label_cat = np.argmax(pred_label, axis=1)
true_label_cat = np.argmax(test_label, axis=1)

print(classification_report(true_label_cat.flatten(), pred_label_cat.flatten()))
# Out:
# 6/6 [==============================] - 2s 124ms/step
#               precision    recall  f1-score   support
#
#            0       0.31      0.18      0.23        90
#            1       0.17      0.11      0.13        46
#            2       0.11      0.36      0.17        28
#            3       0.00      0.00      0.00        10
#
#     accuracy                           0.18       174
#    macro avg       0.15      0.16      0.13       174
# weighted avg       0.23      0.18      0.18       174

# %% [markdown]
# **Since the model is overfitted, it's too biased for high balanced classes**

# %% [markdown]
# **Confusion Matrix**

# %%
conmat = confusion_matrix(true_label_cat.flatten(), pred_label_cat.flatten())
sns.heatmap(conmat, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)

plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
# Assuming your model is trained and `all_meteo_seq_list`, `all_video_list`, and `all_label_list` are prepared
# Prepare the test data (replace with actual test data if needed)
# Here we use the last entry in the lists, but you can use any data for testing

test_meteo_seq = all_meteo_seq_list[-1]  # Or use your test set
test_video_seq = all_video_list[-1]  # Or use your test set
test_labels = all_label_list[-1]  # Actual labels (ground truth)

# Make sure both inputs are NumPy arrays
test_meteo_seq = np.array(test_meteo_seq)
test_video_seq = np.array(test_video_seq)

# Get the model's predictions
predictions = model.predict([test_video_seq, test_meteo_seq])

# If you want to get the predicted class labels
predicted_classes = np.argmax(predictions, axis=-1)

# Assuming the labels are categorical (e.g., one-hot encoded), get the actual labels
actual_classes = np.argmax(test_labels, axis=-1)

# Initialize a dictionary to store the number of correct predictions for each class
correct_class_predictions = {i: {'correct': 0, 'total': 0} for i in range(predictions.shape[-1])}

# Initialize a dictionary to track specific misclassifications (like predicting 2 for 1)
misclassified_pairs = {(1, 2): 0}  # Misclassifications where actual is 1 and predicted is 2

# Compare each prediction with the actual label and count the correct predictions for each class
for actual, predicted in zip(actual_classes, predicted_classes):
    correct_class_predictions[actual]['total'] += 1
    if actual == predicted:
        correct_class_predictions[actual]['correct'] += 1
    else:
        # Track misclassification of actual 1 as predicted 2
        if (actual, predicted) == (1, 2):
            misclassified_pairs[(1, 2)] += 1

# Print the correct predictions for each class
for class_label, counts in correct_class_predictions.items():
    correct = counts['correct']
    total = counts['total']
    accuracy = (correct / total) * 100 if total > 0 else 0
    print(f"Class {class_label}: Correct: {correct} / Total: {total} | Accuracy: {accuracy:.2f}%")

# Print the number of misclassifications where class 1 was predicted as class 2
print(f"Misclassified (Actual 1 -> Predicted 2): {misclassified_pairs[(1, 2)]}")
# Out:
# 6/6 [==============================] - 1s 117ms/step
# Class 0: Correct: 16 / Total: 90 | Accuracy: 17.78%
# Class 1: Correct: 5 / Total: 46 | Accuracy: 10.87%
# Class 2: Correct: 10 / Total: 28 | Accuracy: 35.71%
# Class 3: Correct: 0 / Total: 10 | Accuracy: 0.00%
# Misclassified (Actual 1 -> Predicted 2): 23

# %% [markdown]
# -----

# %% [markdown]
# ## Hybrid Model 2

# %% [markdown]
# Model Architecture
# - One CNN layer
# - Three RNN LSTM layers, with verying units through out layers and activations as desired
# - Also, added dropouts and BatchNormalization

# %%
# Define CNN input
cnn_input = Input(shape=(9, 64, 64, 1))

# CNN Model
cnn = Conv3D(filters=32, kernel_size=(3, 3, 3), activation='relu', padding='same')(cnn_input)
cnn = BatchNormalization()(cnn)
cnn = MaxPooling3D(pool_size=(2, 2, 2))(cnn)
cnn = Dropout(0.20)(cnn)
cnn = Flatten()(cnn)
cnn_output = Dense(32, activation='relu')(cnn)

# Define RNN input
rnn_input = Input(shape=(7, 7))

# RNN Model
rnn = LSTM(128, return_sequences=True, activation='relu')(rnn_input)
rnn = BatchNormalization()(rnn)
rnn = Dropout(0.30)(rnn)
rnn = LSTM(64, return_sequences=True, activation='relu')(rnn)
rnn = BatchNormalization()(rnn)
rnn = Dropout(0.20)(rnn)
rnn = LSTM(32, return_sequences=False, activation='relu')(rnn)
rnn = BatchNormalization()(rnn)
rnn = Dropout(0.10)(rnn)
rnn_output = Dense(24, activation='relu')(rnn)

# Concatenate CNN and RNN outputs
concatenated = Concatenate()([cnn_output, rnn_output])

# Final dense layers
final_dense = Dense(32, activation='relu')(concatenated)
final_output = Dense(4, activation='softmax')(final_dense)

# Model assembly
model = Model(inputs=[cnn_input, rnn_input], outputs=final_output)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_20 (InputLayer)       [(None, 7, 7)]               0         []
#
#  lstm_25 (LSTM)              (None, 7, 128)               69632     ['input_20[0][0]']
#
#  batch_normalization_35 (Ba  (None, 7, 128)               512       ['lstm_25[0][0]']
#  tchNormalization)
#
#  dropout_13 (Dropout)        (None, 7, 128)               0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  input_19 (InputLayer)       [(None, 9, 64, 64, 1)]       0         []
#
#  lstm_26 (LSTM)              (None, 7, 64)                49408     ['dropout_13[0][0]']
#
#  conv3d_9 (Conv3D)           (None, 9, 64, 64, 32)        896       ['input_19[0][0]']
#
#  batch_normalization_36 (Ba  (None, 7, 64)                256       ['lstm_26[0][0]']
#  tchNormalization)
#
#  batch_normalization_34 (Ba  (None, 9, 64, 64, 32)        128       ['conv3d_9[0][0]']
#  tchNormalization)
#
#  dropout_14 (Dropout)        (None, 7, 64)                0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  max_pooling3d_9 (MaxPoolin  (None, 4, 32, 32, 32)        0         ['batch_normalization_34[0][0]
#  g3D)                                                               ']
#
#  lstm_27 (LSTM)              (None, 32)                   12416     ['dropout_14[0][0]']
#
#  dropout_12 (Dropout)        (None, 4, 32, 32, 32)        0         ['max_pooling3d_9[0][0]']
#
#  batch_normalization_37 (Ba  (None, 32)                   128       ['lstm_27[0][0]']
#  tchNormalization)
#
#  flatten_9 (Flatten)         (None, 131072)               0         ['dropout_12[0][0]']
#
#  dropout_15 (Dropout)        (None, 32)                   0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  dense_36 (Dense)            (None, 32)                   4194336   ['flatten_9[0][0]']
#
#  dense_37 (Dense)            (None, 24)                   792       ['dropout_15[0][0]']
#
#  concatenate_9 (Concatenate  (None, 56)                   0         ['dense_36[0][0]',
#  )                                                                   'dense_37[0][0]']
#
#  dense_38 (Dense)            (None, 32)                   1824      ['concatenate_9[0][0]']
#
#  dense_39 (Dense)            (None, 4)                    132       ['dense_38[0][0]']
#
# ==================================================================================================
# Total params: 4330460 (16.52 MB)
# Trainable params: 4329948 (16.52 MB)
# Non-trainable params: 512 (2.00 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# **Model Fitting**

# %%
history = model.fit(
    [train_video, train_meteo],
    train_label,                
    epochs=20,                 
    batch_size=32,               
    class_weight=class_weight_dict,
    validation_split=0.3
)
# Out:
# Epoch 1/20
# 31/31 [==============================] - 66s 2s/step - loss: 2.4370 - accuracy: 0.2174 - val_loss: 1.3463 - val_accuracy: 0.2387
# Epoch 2/20
# 31/31 [==============================] - 60s 2s/step - loss: 1.4977 - accuracy: 0.2738 - val_loss: 1.4068 - val_accuracy: 0.1718
# Epoch 3/20
# 31/31 [==============================] - 60s 2s/step - loss: 1.3912 - accuracy: 0.3026 - val_loss: 1.3865 - val_accuracy: 0.1742
# Epoch 4/20
# 31/31 [==============================] - 60s 2s/step - loss: 1.3628 - accuracy: 0.3179 - val_loss: 1.3727 - val_accuracy: 0.1933
# Epoch 5/20
# 31/31 [==============================] - 60s 2s/step - loss: 1.3418 - accuracy: 0.3272 - val_loss: 1.3636 - val_accuracy: 0.1933
# Epoch 6/20
# 31/31 [==============================] - 61s 2s/step - loss: 1.3585 - accuracy: 0.3610 - val_loss: 1.3713 - val_accuracy: 0.1981
# Epoch 7/20
# 31/31 [==============================] - 60s 2s/step - loss: 1.2148 - accuracy: 0.3846 - val_loss: 1.3225 - val_accuracy: 0.2172
# Epoch 8/20
# 31/31 [==============================] - 60s 2s/step - loss: 1.2244 - accuracy: 0.3877 - val_loss: 1.3270 - val_accuracy: 0.2768
# Epoch 9/20
# 31/31 [==============================] - 60s 2s/step - loss: 1.1716 - accuracy: 0.4092 - val_loss: 1.2804 - val_accuracy: 0.4463
# Epoch 10/20
# 31/31 [==============================] - 60s 2s/step - loss: 1.1095 - accuracy: 0.4626 - val_loss: 1.2863 - val_accuracy: 0.4916
# Epoch 11/20
# 31/31 [==============================] - 60s 2s/step - loss: 1.1128 - accuracy: 0.4636 - val_loss: 1.2803 - val_accuracy: 0.4678
# Epoch 12/20
# 31/31 [==============================] - 61s 2s/step - loss: 1.1170 - accuracy: 0.4369 - val_loss: 1.2242 - val_accuracy: 0.4081
# Epoch 13/20
# 31/31 [==============================] - 60s 2s/step - loss: 1.0161 - accuracy: 0.4872 - val_loss: 1.2599 - val_accuracy: 0.3723
# Epoch 14/20
# 31/31 [==============================] - 61s 2s/step - loss: 0.9348 - accuracy: 0.5446 - val_loss: 1.2159 - val_accuracy: 0.5537
# Epoch 15/20
# 31/31 [==============================] - 60s 2s/step - loss: 0.9699 - accuracy: 0.5097 - val_loss: 1.3288 - val_accuracy: 0.2554
# Epoch 16/20
# 31/31 [==============================] - 61s 2s/step - loss: 0.9208 - accuracy: 0.5159 - val_loss: 1.2588 - val_accuracy: 0.4177
# Epoch 17/20
# 31/31 [==============================] - 60s 2s/step - loss: 0.8178 - accuracy: 0.5723 - val_loss: 1.3854 - val_accuracy: 0.2554
# Epoch 18/20
# 31/31 [==============================] - 60s 2s/step - loss: 0.7740 - accuracy: 0.6010 - val_loss: 1.4200 - val_accuracy: 0.2363
# Epoch 19/20
# 31/31 [==============================] - 61s 2s/step - loss: 0.8107 - accuracy: 0.5692 - val_loss: 1.6154 - val_accuracy: 0.2243
# Epoch 20/20
# 31/31 [==============================] - 61s 2s/step - loss: 0.6812 - accuracy: 0.6308 - val_loss: 1.5495 - val_accuracy: 0.2649

# %% [markdown]
# **Plots for training & validation accuracy & loss values**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# **This time the model did not overfit, though the accuracies are not high**

# %% [markdown]
# **Evaluate the model on the test data**

# %%
# Evaluate the model on the test data
test_loss, test_accuracy = model.evaluate([test_video, test_meteo], test_label)

print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# 6/6 [==============================] - 1s 122ms/step - loss: 1.5764 - accuracy: 0.3276
# Test Loss: 1.576412320137024
# Test Accuracy: 0.32758620381355286

# %% [markdown]
# **Prediction on the test dataset**

# %%
# Predict the test dataset
pred_label = model.predict([test_video, test_meteo])

# Convert predictions from one-hot to labels
pred_label_cat = np.argmax(pred_label, axis=1)
true_label_cat = np.argmax(test_label, axis=1)

print(classification_report(true_label_cat.flatten(), pred_label_cat.flatten()))
# Out:
# 6/6 [==============================] - 1s 124ms/step
#               precision    recall  f1-score   support
#
#            0       0.63      0.19      0.29        90
#            1       0.33      0.50      0.40        46
#            2       0.25      0.61      0.36        28
#            3       0.00      0.00      0.00        10
#
#     accuracy                           0.33       174
#    macro avg       0.30      0.32      0.26       174
# weighted avg       0.45      0.33      0.31       174

# %% [markdown]
# **This model has covers all four classes to predict so far!!**

# %% [markdown]
# **Confusion Matrix**

# %%
conmat = confusion_matrix(true_label_cat.flatten(), pred_label_cat.flatten())
sns.heatmap(conmat, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)

plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
# Assuming your model is trained and `all_meteo_seq_list`, `all_video_list`, and `all_label_list` are prepared
# Prepare the test data (replace with actual test data if needed)
# Here we use the last entry in the lists, but you can use any data for testing

test_meteo_seq = all_meteo_seq_list[-1]  # Or use your test set
test_video_seq = all_video_list[-1]  # Or use your test set
test_labels = all_label_list[-1]  # Actual labels (ground truth)

# Make sure both inputs are NumPy arrays
test_meteo_seq = np.array(test_meteo_seq)
test_video_seq = np.array(test_video_seq)

# Get the model's predictions
predictions = model.predict([test_video_seq, test_meteo_seq])

# If you want to get the predicted class labels
predicted_classes = np.argmax(predictions, axis=-1)

# Assuming the labels are categorical (e.g., one-hot encoded), get the actual labels
actual_classes = np.argmax(test_labels, axis=-1)

# Initialize a dictionary to store the number of correct predictions for each class
correct_class_predictions = {i: {'correct': 0, 'total': 0} for i in range(predictions.shape[-1])}

# Initialize a dictionary to track specific misclassifications (like predicting 2 for 1)
misclassified_pairs = {(1, 2): 0}  # Misclassifications where actual is 1 and predicted is 2

# Compare each prediction with the actual label and count the correct predictions for each class
for actual, predicted in zip(actual_classes, predicted_classes):
    correct_class_predictions[actual]['total'] += 1
    if actual == predicted:
        correct_class_predictions[actual]['correct'] += 1
    else:
        # Track misclassification of actual 1 as predicted 2
        if (actual, predicted) == (1, 2):
            misclassified_pairs[(1, 2)] += 1

# Print the correct predictions for each class
for class_label, counts in correct_class_predictions.items():
    correct = counts['correct']
    total = counts['total']
    accuracy = (correct / total) * 100 if total > 0 else 0
    print(f"Class {class_label}: Correct: {correct} / Total: {total} | Accuracy: {accuracy:.2f}%")

# Print the number of misclassifications where class 1 was predicted as class 2
print(f"Misclassified (Actual 1 -> Predicted 2): {misclassified_pairs[(1, 2)]}")
# Out:
# 6/6 [==============================] - 1s 138ms/step
# Class 0: Correct: 17 / Total: 90 | Accuracy: 18.89%
# Class 1: Correct: 23 / Total: 46 | Accuracy: 50.00%
# Class 2: Correct: 17 / Total: 28 | Accuracy: 60.71%
# Class 3: Correct: 0 / Total: 10 | Accuracy: 0.00%
# Misclassified (Actual 1 -> Predicted 2): 14

# %% [markdown]
# -----

# %% [markdown]
# # Hybrid Model 3

# %% [markdown]
# Model Architecture
# - One CNN layer
# - Two RNN LSTM layers, with verying units through out layers and activations as desired
# - BatchNormalization and no dropouts this time

# %%
# CNN Model
cnn_input = Input(shape=(9, 64, 64, 1))
cnn = Conv3D(filters=32, kernel_size=(3, 3, 3), padding='same')(cnn_input)
cnn = BatchNormalization()(cnn)
cnn = MaxPooling3D(pool_size=(2, 2, 2))(cnn)

cnn = Flatten()(cnn)
cnn_output = Dense(16, activation='relu')(cnn)

# RNN Model
rnn_input = Input(shape=(7, 7))
rnn = LSTM(64, return_sequences=True)(rnn_input)
rnn = BatchNormalization()(rnn)
rnn = LSTM(32, return_sequences=False)(rnn)
rnn = BatchNormalization()(rnn)
rnn_output = Dense(24, activation='relu')(rnn)

# Concatenation and final layers
concatenated = Concatenate()([cnn_output, rnn_output])

final_dense = Dense(32, activation='relu')(concatenated)
final_output = Dense(4, activation='softmax')(final_dense)

# Final model assembly
model = Model(inputs=[cnn_input, rnn_input], outputs=final_output)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 9, 64, 64, 1)]       0         []
#
#  input_2 (InputLayer)        [(None, 7, 7)]               0         []
#
#  conv3d (Conv3D)             (None, 9, 64, 64, 32)        896       ['input_1[0][0]']
#
#  lstm (LSTM)                 (None, 7, 64)                18432     ['input_2[0][0]']
#
#  batch_normalization (Batch  (None, 9, 64, 64, 32)        128       ['conv3d[0][0]']
#  Normalization)
#
#  batch_normalization_1 (Bat  (None, 7, 64)                256       ['lstm[0][0]']
#  chNormalization)
#
#  max_pooling3d (MaxPooling3  (None, 4, 32, 32, 32)        0         ['batch_normalization[0][0]']
#  D)
#
#  lstm_1 (LSTM)               (None, 32)                   12416     ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  flatten (Flatten)           (None, 131072)               0         ['max_pooling3d[0][0]']
#
#  batch_normalization_2 (Bat  (None, 32)                   128       ['lstm_1[0][0]']
#  chNormalization)
#
#  dense (Dense)               (None, 16)                   2097168   ['flatten[0][0]']
#
#  dense_1 (Dense)             (None, 24)                   792       ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  concatenate (Concatenate)   (None, 40)                   0         ['dense[0][0]',
#                                                                      'dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 32)                   1312      ['concatenate[0][0]']
#
#  dense_3 (Dense)             (None, 4)                    132       ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 2131660 (8.13 MB)
# Trainable params: 2131404 (8.13 MB)
# Non-trainable params: 256 (1.00 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# **Model Fitting**

# %%
history = model.fit(
    [train_video, train_meteo],
    train_label,                
    epochs=40,                 
    batch_size=32,               
    class_weight=class_weight_dict,
    validation_split=0.2
)
# Out:
# Epoch 1/40
# 35/35 [==============================] - 73s 2s/step - loss: 2.5678 - accuracy: 0.2735 - val_loss: 1.3839 - val_accuracy: 0.2007
# Epoch 2/40
# 35/35 [==============================] - 69s 2s/step - loss: 1.3944 - accuracy: 0.3022 - val_loss: 1.3922 - val_accuracy: 0.1720
# Epoch 3/40
# 35/35 [==============================] - 68s 2s/step - loss: 1.3690 - accuracy: 0.2960 - val_loss: 1.3870 - val_accuracy: 0.1864
# Epoch 4/40
# 35/35 [==============================] - 68s 2s/step - loss: 1.3533 - accuracy: 0.3193 - val_loss: 1.3750 - val_accuracy: 0.1864
# Epoch 5/40
# 35/35 [==============================] - 69s 2s/step - loss: 1.3363 - accuracy: 0.2951 - val_loss: 1.3742 - val_accuracy: 0.2079
# Epoch 6/40
# 35/35 [==============================] - 68s 2s/step - loss: 1.3223 - accuracy: 0.3363 - val_loss: 1.3804 - val_accuracy: 0.1900
# Epoch 7/40
# 35/35 [==============================] - 68s 2s/step - loss: 1.2983 - accuracy: 0.3471 - val_loss: 1.3507 - val_accuracy: 0.2652
# Epoch 8/40
# 35/35 [==============================] - 68s 2s/step - loss: 1.2766 - accuracy: 0.3525 - val_loss: 1.3236 - val_accuracy: 0.3513
# Epoch 9/40
# 35/35 [==============================] - 68s 2s/step - loss: 1.2696 - accuracy: 0.3462 - val_loss: 1.3469 - val_accuracy: 0.2796
# Epoch 10/40
# 35/35 [==============================] - 68s 2s/step - loss: 1.2548 - accuracy: 0.3372 - val_loss: 1.3206 - val_accuracy: 0.3262
# Epoch 11/40
# 35/35 [==============================] - 68s 2s/step - loss: 1.2586 - accuracy: 0.3587 - val_loss: 1.3322 - val_accuracy: 0.2366
# Epoch 12/40
# 35/35 [==============================] - 69s 2s/step - loss: 1.2076 - accuracy: 0.3910 - val_loss: 1.3632 - val_accuracy: 0.2007
# Epoch 13/40
# 35/35 [==============================] - 69s 2s/step - loss: 1.2121 - accuracy: 0.3776 - val_loss: 1.2685 - val_accuracy: 0.3047
# Epoch 14/40
# 35/35 [==============================] - 68s 2s/step - loss: 1.2018 - accuracy: 0.3848 - val_loss: 1.3752 - val_accuracy: 0.3082
# Epoch 15/40
# 35/35 [==============================] - 69s 2s/step - loss: 1.1776 - accuracy: 0.3848 - val_loss: 1.2196 - val_accuracy: 0.3692
# Epoch 16/40
# 35/35 [==============================] - 68s 2s/step - loss: 1.1440 - accuracy: 0.3955 - val_loss: 1.2294 - val_accuracy: 0.4122
# Epoch 17/40
# 35/35 [==============================] - 69s 2s/step - loss: 1.1099 - accuracy: 0.4108 - val_loss: 1.2507 - val_accuracy: 0.3835
# Epoch 18/40
# 35/35 [==============================] - 69s 2s/step - loss: 1.0989 - accuracy: 0.4224 - val_loss: 1.2866 - val_accuracy: 0.4265
# Epoch 19/40
# 35/35 [==============================] - 69s 2s/step - loss: 1.1091 - accuracy: 0.4099 - val_loss: 1.3658 - val_accuracy: 0.3297
# Epoch 20/40
# 35/35 [==============================] - 69s 2s/step - loss: 1.0715 - accuracy: 0.4278 - val_loss: 1.2514 - val_accuracy: 0.3620
# Epoch 21/40
# 35/35 [==============================] - 69s 2s/step - loss: 1.0588 - accuracy: 0.4520 - val_loss: 1.2901 - val_accuracy: 0.3943
# Epoch 22/40
# 35/35 [==============================] - 69s 2s/step - loss: 1.0461 - accuracy: 0.4368 - val_loss: 1.2601 - val_accuracy: 0.4265
# Epoch 23/40
# 35/35 [==============================] - 68s 2s/step - loss: 0.9986 - accuracy: 0.4717 - val_loss: 1.3971 - val_accuracy: 0.3082
# Epoch 24/40
# 35/35 [==============================] - 69s 2s/step - loss: 0.9929 - accuracy: 0.4682 - val_loss: 1.3211 - val_accuracy: 0.3871
# Epoch 25/40
# 35/35 [==============================] - 68s 2s/step - loss: 0.9908 - accuracy: 0.4583 - val_loss: 1.3024 - val_accuracy: 0.4265
# Epoch 26/40
# 35/35 [==============================] - 69s 2s/step - loss: 0.9912 - accuracy: 0.4726 - val_loss: 1.4292 - val_accuracy: 0.3082
# Epoch 27/40
# 35/35 [==============================] - 69s 2s/step - loss: 0.9616 - accuracy: 0.4780 - val_loss: 1.3442 - val_accuracy: 0.4194
# Epoch 28/40
# 35/35 [==============================] - 69s 2s/step - loss: 0.9435 - accuracy: 0.4996 - val_loss: 1.5188 - val_accuracy: 0.2616
# Epoch 29/40
# 35/35 [==============================] - 68s 2s/step - loss: 0.8956 - accuracy: 0.5139 - val_loss: 1.3331 - val_accuracy: 0.4444
# Epoch 30/40
# 35/35 [==============================] - 69s 2s/step - loss: 0.8844 - accuracy: 0.5283 - val_loss: 1.5508 - val_accuracy: 0.3656
# Epoch 31/40
# 35/35 [==============================] - 69s 2s/step - loss: 0.8930 - accuracy: 0.5363 - val_loss: 1.5589 - val_accuracy: 0.2903
# Epoch 32/40
# 35/35 [==============================] - 69s 2s/step - loss: 0.8503 - accuracy: 0.5354 - val_loss: 1.4624 - val_accuracy: 0.3692
# Epoch 33/40
# 35/35 [==============================] - 69s 2s/step - loss: 0.8576 - accuracy: 0.5399 - val_loss: 1.5204 - val_accuracy: 0.3620
# Epoch 34/40
# 35/35 [==============================] - 68s 2s/step - loss: 0.8284 - accuracy: 0.5480 - val_loss: 1.5084 - val_accuracy: 0.3835
# Epoch 35/40
# 35/35 [==============================] - 68s 2s/step - loss: 0.8556 - accuracy: 0.5525 - val_loss: 1.5793 - val_accuracy: 0.3262
# Epoch 36/40
# 35/35 [==============================] - 69s 2s/step - loss: 0.8423 - accuracy: 0.5623 - val_loss: 1.3957 - val_accuracy: 0.4373
# Epoch 37/40
# 35/35 [==============================] - 69s 2s/step - loss: 0.7871 - accuracy: 0.5578 - val_loss: 1.5277 - val_accuracy: 0.3333
# Epoch 38/40
# 35/35 [==============================] - 68s 2s/step - loss: 0.8096 - accuracy: 0.5704 - val_loss: 1.4776 - val_accuracy: 0.3226
# Epoch 39/40
# 35/35 [==============================] - 69s 2s/step - loss: 0.8074 - accuracy: 0.5695 - val_loss: 1.5058 - val_accuracy: 0.3943
# Epoch 40/40
# 35/35 [==============================] - 69s 2s/step - loss: 0.7784 - accuracy: 0.5794 - val_loss: 1.4873 - val_accuracy: 0.4158

# %% [markdown]
# **Plots for training & validation accuracy & loss values**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# **Evaluate the model on the test data**

# %%
# Evaluate the model on the test data
test_loss, test_accuracy = model.evaluate([test_video, test_meteo], test_label)

print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# 6/6 [==============================] - 1s 123ms/step - loss: 1.8793 - accuracy: 0.3161
# Test Loss: 1.879341959953308
# Test Accuracy: 0.31609195470809937

# %% [markdown]
# **Prediction on the test dataset**

# %%
# Predict the test dataset
pred_label = model.predict([test_video, test_meteo])

# Convert predictions from one-hot to labels
pred_label_cat = np.argmax(pred_label, axis=1)
true_label_cat = np.argmax(test_label, axis=1)

print(classification_report(true_label_cat.flatten(), pred_label_cat.flatten()))
# Out:
# 6/6 [==============================] - 2s 116ms/step
#               precision    recall  f1-score   support
#
#            0       0.49      0.44      0.47        90
#            1       0.21      0.22      0.22        46
#            2       0.11      0.14      0.12        28
#            3       0.14      0.10      0.12        10
#
#     accuracy                           0.32       174
#    macro avg       0.24      0.23      0.23       174
# weighted avg       0.33      0.32      0.32       174

# %% [markdown]
# **This Model has also performed better to predict between four classes but not good with accuracies, since the data is less and even if I train for more epochs its overfitting**

# %% [markdown]
# **Confusion Matrix**

# %%
conmat = confusion_matrix(true_label_cat.flatten(), pred_label_cat.flatten())
sns.heatmap(conmat, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)

plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
# Assuming your model is trained and `all_meteo_seq_list`, `all_video_list`, and `all_label_list` are prepared
# Prepare the test data (replace with actual test data if needed)
# Here we use the last entry in the lists, but you can use any data for testing

test_meteo_seq = all_meteo_seq_list[-1]  # Or use your test set
test_video_seq = all_video_list[-1]  # Or use your test set
test_labels = all_label_list[-1]  # Actual labels (ground truth)

# Make sure both inputs are NumPy arrays
test_meteo_seq = np.array(test_meteo_seq)
test_video_seq = np.array(test_video_seq)

# Get the model's predictions
predictions = model.predict([test_video_seq, test_meteo_seq])

# If you want to get the predicted class labels
predicted_classes = np.argmax(predictions, axis=-1)

# Assuming the labels are categorical (e.g., one-hot encoded), get the actual labels
actual_classes = np.argmax(test_labels, axis=-1)

# Initialize a dictionary to store the number of correct predictions for each class
correct_class_predictions = {i: {'correct': 0, 'total': 0} for i in range(predictions.shape[-1])}

# Initialize a dictionary to track specific misclassifications (like predicting 2 for 1)
misclassified_pairs = {(1, 2): 0}  # Misclassifications where actual is 1 and predicted is 2

# Compare each prediction with the actual label and count the correct predictions for each class
for actual, predicted in zip(actual_classes, predicted_classes):
    correct_class_predictions[actual]['total'] += 1
    if actual == predicted:
        correct_class_predictions[actual]['correct'] += 1
    else:
        # Track misclassification of actual 1 as predicted 2
        if (actual, predicted) == (1, 2):
            misclassified_pairs[(1, 2)] += 1

# Print the correct predictions for each class
for class_label, counts in correct_class_predictions.items():
    correct = counts['correct']
    total = counts['total']
    accuracy = (correct / total) * 100 if total > 0 else 0
    print(f"Class {class_label}: Correct: {correct} / Total: {total} | Accuracy: {accuracy:.2f}%")

# Print the number of misclassifications where class 1 was predicted as class 2
print(f"Misclassified (Actual 1 -> Predicted 2): {misclassified_pairs[(1, 2)]}")
# Out:
# 6/6 [==============================] - 1s 120ms/step
# Class 0: Correct: 40 / Total: 90 | Accuracy: 44.44%
# Class 1: Correct: 10 / Total: 46 | Accuracy: 21.74%
# Class 2: Correct: 4 / Total: 28 | Accuracy: 14.29%
# Class 3: Correct: 1 / Total: 10 | Accuracy: 10.00%
# Misclassified (Actual 1 -> Predicted 2): 8

# %% [markdown]
# -----

# %% [markdown]
# ## Conclusion:
#
# **The hybrid model 3 with One CNN layer and 3 RNN LSTM worked well to predict two days in advance covering all four classes, although the accuracies are not that great because of less data after doing aggregations in daily level**
